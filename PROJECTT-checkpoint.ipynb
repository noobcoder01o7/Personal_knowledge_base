# %%
# !pip install --upgrade langchain langchain-core langchain_community langchain_ollama langchain_text_splitters langchain_chroma streamlit
# !pip install tf-keras
# Out:
# Requirement already satisfied: langchain in c:\users\amit\anaconda3\lib\site-packages (1.0.7)
# Requirement already satisfied: langchain-core in c:\users\amit\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: langchain_community in c:\users\amit\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain_ollama in c:\users\amit\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: langchain_text_splitters in c:\users\amit\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: langchain_chroma in c:\users\amit\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: streamlit in c:\users\amit\anaconda3\lib\site-packages (1.51.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\amit\anaconda3\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\amit\anaconda3\lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\amit\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\amit\anaconda3\lib\site-packages (from langchain-core) (0.4.31)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\amit\anaconda3\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\amit\anaconda3\lib\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\amit\anaconda3\lib\site-packages (from langchain-core) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\amit\anaconda3\lib\site-packages (from langchain-core) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\amit\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\amit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\amit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\amit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\amit\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\amit\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\amit\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\amit\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\amit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\amit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\amit\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: anyio in c:\users\amit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.7.0)
# Requirement already satisfied: certifi in c:\users\amit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\amit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\amit\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\amit\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\amit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\amit\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\amit\anaconda3\lib\site-packages (from langchain_community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\amit\anaconda3\lib\site-packages (from langchain_community) (2.0.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\amit\anaconda3\lib\site-packages (from langchain_community) (3.11.10)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\amit\anaconda3\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\amit\anaconda3\lib\site-packages (from langchain_community) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\amit\anaconda3\lib\site-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\amit\anaconda3\lib\site-packages (from langchain_community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\amit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\amit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\amit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\amit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\amit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\amit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\amit\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\amit\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\amit\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\amit\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\amit\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\amit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amit\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\amit\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\amit\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.0.0)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in c:\users\amit\anaconda3\lib\site-packages (from langchain_ollama) (0.6.0)
# Requirement already satisfied: chromadb<2.0.0,>=1.0.20 in c:\users\amit\anaconda3\lib\site-packages (from langchain_chroma) (1.1.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\amit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.37.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.23.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.75.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\amit\anaconda3\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\amit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\amit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\amit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\amit\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.9.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (6.32.1)
# Requirement already satisfied: pyarrow<22,>=7.0 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\amit\anaconda3\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\amit\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\amit\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: colorama in c:\users\amit\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\amit\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\amit\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amit\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\amit\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: pyproject_hooks in c:\users\amit\anaconda3\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\amit\anaconda3\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\amit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\amit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\amit\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.22.3)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\amit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.41.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\amit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\amit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\amit\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\amit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\amit\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\amit\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.4.8)
# Requirement already satisfied: coloredlogs in c:\users\amit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\amit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (25.2.10)
# Requirement already satisfied: sympy in c:\users\amit\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\amit\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\amit\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\amit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\amit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\amit\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\amit\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.58b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\amit\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\amit\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\amit\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.1.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\amit\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.35.3)
# Requirement already satisfied: filelock in c:\users\amit\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\amit\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain_chroma) (2025.3.2)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\amit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\amit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\amit\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain_chroma) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\amit\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\amit\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\amit\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\amit\anaconda3\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain_chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\amit\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain_chroma) (1.3.0)
# Requirement already satisfied: tf-keras in c:\users\amit\anaconda3\lib\site-packages (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\amit\anaconda3\lib\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (6.32.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.11.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.12.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\amit\anaconda3\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\amit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amit\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\amit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.8)
# Requirement already satisfied: pillow in c:\users\amit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\amit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\amit\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\amit\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\amit\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (13.9.4)
# Requirement already satisfied: namex in c:\users\amit\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\amit\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\amit\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\amit\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\amit\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\amit\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)

# %%
import os
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_ollama import OllamaEmbeddings, OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
DATA_PATH = "documents"
CHROMA_PATH = "chroma"

# FIX: Define models clearly
EMBEDDING_MODEL = "nomic-embed-text" 
LLM_MODEL = "llama3"

# %%
loader = DirectoryLoader(DATA_PATH, glob="**/*.pdf", loader_cls=PyPDFLoader, silent_errors=True)
documents = loader.load()

if not documents:
    print(f"No PDF documents found in '{DATA_PATH}'. Please add your notes.")
else:
    print(f"Loaded {len(documents)} document(s).")
    
    # Split documents
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    chunks = text_splitter.split_documents(documents)
    print(f"Split documents into {len(chunks)} chunks.")
# Out:
# Loaded 120 document(s).
# Split documents into 337 chunks.

# %%
def ingest_documents():
    if not 'chunks' in globals() or not chunks:
        print("Error: No chunks found. Please run the 'Load and Split' cell first.")
        return

    print(f"Creating embeddings with '{EMBEDDING_MODEL}' and storing in Chroma... (This may take a moment)")
    
    # FIX: Use the fast embedding model
    embeddings = OllamaEmbeddings(model=EMBEDDING_MODEL)
    
    db = Chroma.from_documents(
        documents=chunks, 
        embedding=embeddings, 
        persist_directory=CHROMA_PATH
    )
    print(f"Successfully saved {len(chunks)} chunks to Chroma DB at '{CHROMA_PATH}'.")

# Run the ingestion
ingest_documents()
# Out:
# Creating embeddings with 'nomic-embed-text' and storing in Chroma... (This may take a moment)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[11], line 19
#      16     print(f"Successfully saved {len(chunks)} chunks to Chroma DB at '{CHROMA_PATH}'.")
#      18 # Run the ingestion
# ---> 19 ingest_documents()
#
# Cell In[11], line 11, in ingest_documents()
#       8 # FIX: Use the fast embedding model
#       9 embeddings = OllamaEmbeddings(model=EMBEDDING_MODEL)
# ---> 11 db = Chroma.from_documents(
#      12     documents=chunks,
#      13     embedding=embeddings,
#      14     persist_directory=CHROMA_PATH
#      15 )
#      16 print(f"Successfully saved {len(chunks)} chunks to Chroma DB at '{CHROMA_PATH}'.")
#
# File ~\anaconda3\Lib\site-packages\langchain_chroma\vectorstores.py:1377, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, host, port, headers, chroma_cloud_api_key, tenant, database, client_settings, client, collection_metadata, collection_configuration, ssl, **kwargs)
#    1375 if ids is None:
#    1376     ids = [doc.id if doc.id else str(uuid.uuid4()) for doc in documents]
# -> 1377 return cls.from_texts(
#    1378     texts=texts,
#    1379     embedding=embedding,
#    1380     metadatas=metadatas,
#    1381     ids=ids,
#    1382     collection_name=collection_name,
#    1383     persist_directory=persist_directory,
#    1384     host=host,
#    1385     port=port,
#    1386     ssl=ssl,
#    1387     headers=headers,
#    1388     chroma_cloud_api_key=chroma_cloud_api_key,
#    1389     tenant=tenant,
#    1390     database=database,
#    1391     client_settings=client_settings,
#    1392     client=client,
#    1393     collection_metadata=collection_metadata,
#    1394     collection_configuration=collection_configuration,
#    1395     **kwargs,
#    1396 )
#
# File ~\anaconda3\Lib\site-packages\langchain_chroma\vectorstores.py:1311, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, host, port, headers, chroma_cloud_api_key, tenant, database, client_settings, client, collection_metadata, collection_configuration, ssl, **kwargs)
#    1303     from chromadb.utils.batch_utils import create_batches
#    1305     for batch in create_batches(
#    1306         api=chroma_collection._client,
#    1307         ids=ids,
#    1308         metadatas=metadatas,  # type: ignore[arg-type]
#    1309         documents=texts,
#    1310     ):
# -> 1311         chroma_collection.add_texts(
#    1312             texts=batch[3] if batch[3] else [],
#    1313             metadatas=batch[2] if batch[2] else None,  # type: ignore[arg-type]
#    1314             ids=batch[0],
#    1315         )
#    1316 else:
#    1317     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
# File ~\anaconda3\Lib\site-packages\langchain_chroma\vectorstores.py:644, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     642 ids_with_metadata = [ids[idx] for idx in non_empty_ids]
#     643 try:
# --> 644     self._collection.upsert(
#     645         metadatas=metadatas,  # type: ignore[arg-type]
#     646         embeddings=embeddings_with_metadatas,  # type: ignore[arg-type]
#     647         documents=texts_with_metadatas,
#     648         ids=ids_with_metadata,
#     649     )
#     650 except ValueError as e:
#     651     if "Expected metadata value to be" in str(e):
#
# File ~\anaconda3\Lib\site-packages\chromadb\api\models\Collection.py:451, in Collection.upsert(self, ids, embeddings, metadatas, documents, images, uris)
#     431 """Update the embeddings, metadatas or documents for provided ids, or create them if they don't exist.
#     432
#     433 Args:
#    (...)
#     440     None
#     441 """
#     442 upsert_request = self._validate_and_prepare_upsert_request(
#     443     ids=ids,
#     444     embeddings=embeddings,
#    (...)
#     448     uris=uris,
#     449 )
# --> 451 self._client._upsert(
#     452     collection_id=self.id,
#     453     ids=upsert_request["ids"],
#     454     embeddings=upsert_request["embeddings"],
#     455     metadatas=upsert_request["metadatas"],
#     456     documents=upsert_request["documents"],
#     457     uris=upsert_request["uris"],
#     458     tenant=self.tenant,
#     459     database=self.database,
#     460 )
#
# File ~\anaconda3\Lib\site-packages\chromadb\api\rust.py:478, in RustBindingsAPI._upsert(self, collection_id, ids, embeddings, metadatas, documents, uris, tenant, database)
#     466 @override
#     467 def _upsert(
#     468     self,
#    (...)
#     476     database: str = DEFAULT_DATABASE,
#     477 ) -> bool:
# --> 478     return self.bindings.upsert(
#     479         str(collection_id),
#     480         ids,
#     481         embeddings,
#     482         metadatas,
#     483         documents,
#     484         uris,
#     485         tenant,
#     486         database,
#     487     )
#
# InvalidArgumentError: Collection expecting embedding with dimension of 4096, got 768

# %%
def query_rag(question_text: str):
    print(f"Preparing to query with '{EMBEDDING_MODEL}' and '{LLM_MODEL}'...")

    # Load embeddings
    # FIX: Must use the SAME embedding model used for ingestion
    embeddings = OllamaEmbeddings(model=EMBEDDING_MODEL)
    
    # Load existing DB
    db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embeddings)
    retriever = db.as_retriever()

    # Define prompt
    prompt_template = """
    Answer the question based only on the following context:
    {context}
    ---
    Answer the question based on the above context: {question}
    """
    prompt = ChatPromptTemplate.from_template(prompt_template)

    # Define model
    # FIX: Use the LLM for generating the final answer
    model = OllamaLLM(model=LLM_MODEL)

    # Define RAG chain
    chain = (
        {"context": retriever, "question": RunnablePassthrough()}
        | prompt
        | model
        | StrOutputParser()
    )

    print("Querying the AI...")
    response = chain.invoke(question_text)
    return response

# %%
my_question = "What is Machine learning?" 
answer = query_rag(my_question)

print("\n--- AI Answer ---\n")
print(answer)
